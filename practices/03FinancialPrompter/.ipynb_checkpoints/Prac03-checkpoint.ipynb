# %% [markdown]
# ### Financial News Scrapper
#
# 이번 실습에서는 Google News로부터 종목을 검색해 투자 조언을 생성하는 LLM을 생성하는 것으로 한다.

# %% [markdown]
# ### 1. Google Search function
#
# Google News에서 내용을 파싱하는 함수가 다음과 같이 존재한다. 이를 실행하기 위해서는 다음과 같은 라이브러리가 필요하다.
#
# - `Selenium` : pip install selenium
# - `webdriver_manager` : pip3 install webdriver_manager
# - `Newspaper` : pip3 install newspaper3k
# - `lxml_html_clean` : pip install lxml_html_clean

# %%
# import package
from bs4 import BeautifulSoup
import requests
import urllib
import re
import pandas as pd
from newspaper import Article
from selenium import webdriver

# %%
def search_from_google(asset:str, page_nums:int) -> pd.DataFrame :
    '''
    google news로부터 검색을 한 뒤, selenium을 통해 뉴스 데이터들을 가져옵니다.
    :param asset: 검색할 자산
    :param page_nums: 뉴스를 검색할 총 페이지의 수
    :return: news data가 들어있는 DataFrame
    '''
    keyword = f'{asset} buying reason'
    news_df = pd.DataFrame()
    
    # selenium headless mode
    options = webdriver.ChromeOptions()
    options.add_argument('headless')
    driver = webdriver.Chrome(options=options)
    
    for page_num in range(0, page_nums-1):
        # google news crawling
        url = f'https://www.google.com/search?q={keyword}&sca_esv=1814fa2a4600643d&tbas=0&tbs=qdr:m&tbm=nws&ei=rE3pZeLxNeHX1e8PpdOcMA&start={page_num}&sa=N&ved=2ahUKEwji9-zrsuGEAxXha_UHHaUpBwYQ8tMDegQIBBAE&biw=2560&bih=1313&dpr=1'
        req = requests.get(url)
        content = req.content
        soup = BeautifulSoup(content, 'html.parser')
    
        # last page check
        if soup.select('div.BNeawe.vvjwJb') == []: break
    
        title_list = [t.text for t in soup.select('div.BNeawe.vvjwJb')]  # title
        url_list = []
    
        # url
        for u in soup.select('a'):
            for t in title_list:
                if t in u.text:
                    temp_url = urllib.parse.unquote(u['href'])
                    temp_url = re.findall('http\S+&sa',temp_url)[0][:-3]
                    url_list.append(temp_url)
    
        # article
        for ind, news_url in enumerate(url_list):
            try:
                article = Article(url=news_url)
                article.download()
                article.parse()    
                news_article = article.text
            except:  # ssl error
                driver.get(news_url)
                article.download(input_html=driver.page_source)
                article.parse()
                news_article = article.text
    
            news_df = pd.concat([news_df, pd.DataFrame([[title_list[ind], news_article, news_url]])])
    
        news_df[0] = news_df[0].apply(lambda x: re.sub('\s+',' ',x))
        news_df = news_df.reset_index(drop=True)
    
    news_df.columns = ['Title','Contents','URL']
    
    return news_df

# %%
search_result = search_from_google('META', 3)

# %%
# 출력 결과의 확인
search_result.head()
# Out:
#                                                Title  \
# 0  Why Meta Platforms (META) Is the Best Blue Chi...
# 1  Should I buy Meta shares? How to profit from I...
# 2         Why Meta Platforms Stock Slumped on Monday
# 3  Nvidia Rises On Amazon's 'Obvious' Partnership...
# 4  Elon Musk buying TikTok seems like a stretch —...
#
#                                             Contents  \
# 0  We recently published a list of 10 Best Blue C...
# 1  Important information Your capital is at risk....
# 2  Meta Platforms (META 0.35%) received some disc...
# 3  Access to this page has been denied because we...
# 4  Could Elon Musk buy TikTok?\n\nSeveral reports...
#
#                                                  URL
# 0  https://finance.yahoo.com/news/why-meta-platfo...
# 1  https://www.thetimes.com/money-mentor/investin...
# 2  https://www.fool.com/investing/2025/01/13/why-...
# 3  https://www.investors.com/research/nvda-stock-...
# 4  https://www.businessinsider.com/elon-musk-buyi...

# %% [markdown]
# ### 2.

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.llms import OpenAI
import os
import openai

with open("../../config/api.key", "r") as f:
    lines = f.readlines()
    config = lines[0].strip()

openai.api_key = config
os.environ["OPENAI_API_KEY"] = config

Asset = 'META'

def extract_reason(row) :
    try :
        res = chain.predict(
            title=row["Title"],
            content=row["Contents"]
        )
    except :
        res = chain.predict(
            title=row["Title"],
            content=row["Contents"][:4096]
        )
    return res

# 🔹 LLM 모델 설정
llm = OpenAI(temperature = 0)

template = f"""
당신은 전문적인 금융 투자자입니다. 
제공하는 뉴스기사의 제목과 본문을 읽고 {Asset}종목의 매수를 추천하는 이유를 한 가지만 설명해주세요.
본문의 내용이 {Asset} 종목과 무관한 경우, '연관 없는 내용입니다' 라고 채워주세요.
이유는 50자 내외로 짧게 생성하며, 경어체가 아닌 ~이다. ~되었다. 으로 끝냅니다.
수치 데이터 중심으로 설명해 주세요.

예시 : 
2024년 4분기 수익성이 개선되었다.

한국어가 아닌 경우 한국어로 우선 번역합니다.
번역한 텍스트는 출력하지 않습니다.

""" + """
Title : {title}
Content : {content}

Answer : 
"""

prompt = PromptTemplate(
    input_variables = ['title','content'],
    template = template
)

chain = LLMChain(
    llm = llm,
    prompt = prompt
)

search_result['reason'] = search_result.apply(extract_reason, axis = 1)
# Out:
# /var/folders/1q/pl9tj55n57s9jg28npxw61n80000gn/T/ipykernel_2125/2083587511.py:30: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   llm = OpenAI(temperature = 0)
# /var/folders/1q/pl9tj55n57s9jg28npxw61n80000gn/T/ipykernel_2125/2083587511.py:57: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(

# %%
search_result
# Out:
#                                                 Title  \
# 0   Why Meta Platforms (META) Is the Best Blue Chi...
# 1   Should I buy Meta shares? How to profit from I...
# 2          Why Meta Platforms Stock Slumped on Monday
# 3   Nvidia Rises On Amazon's 'Obvious' Partnership...
# 4   Elon Musk buying TikTok seems like a stretch —...
# 5      What Zuckerberg Risks by Following Musk’s Lead
# 6   Why Mark Zuckerberg Is Ditching Human Fact-Che...
# 7   Why Did Apple and Meta Platforms Rise While Nv...
# 8   Meta Platforms Continues to Prove Why It's a P...
# 9   Meta Platforms Reports Q4 Earnings on January ...
# 10  Should I buy Meta shares? How to profit from I...
# 11         Why Meta Platforms Stock Slumped on Monday
# 12  Nvidia Rises On Amazon's 'Obvious' Partnership...
# 13  Elon Musk buying TikTok seems like a stretch —...
# 14     What Zuckerberg Risks by Following Musk’s Lead
# 15  Why Mark Zuckerberg Is Ditching Human Fact-Che...
# 16  Why Did Apple and Meta Platforms Rise While Nv...
# 17  Markets News, January 27, 2025: Nasdaq Composi...
# 18  Meta Platforms Continues to Prove Why It's a P...
# 19  Meta Platforms Reports Q4 Earnings on January ...
#
#                                              Contents  \
# 0   We recently published a list of 10 Best Blue C...
# 1   Important information Your capital is at risk....
# 2   Meta Platforms (META 0.35%) received some disc...
# 3   Access to this page has been denied because we...
# 4   Could Elon Musk buy TikTok?\n\nSeveral reports...
# 5   On Tuesday, Meta CEO Mark Zuckerberg announced...
# 6   Michael Calore: Zoë's snapping her fingers in ...
# 7   Jan. 27 was a wild day in the stock market as ...
# 8   Meta Platforms Today META Meta Platforms $714....
# 9   Switch the Market flag\n\nOpen the menu and sw...
# 10  Important information Your capital is at risk....
# 11  Meta Platforms (META 0.35%) received some disc...
# 12  Access to this page has been denied because we...
# 13  Could Elon Musk buy TikTok?\n\nSeveral reports...
# 14  On Tuesday, Meta CEO Mark Zuckerberg announced...
# 15  Michael Calore: Zoë's snapping her fingers in ...
# 16  Jan. 27 was a wild day in the stock market as ...
# 17  Nvidia Shed's Nearly $600 Billion in Market Va...
# 18  Meta Platforms Today META Meta Platforms $714....
# 19  Switch the Market flag\n\nOpen the menu and sw...
#
#                                                   URL  \
# 0   https://finance.yahoo.com/news/why-meta-platfo...
# 1   https://www.thetimes.com/money-mentor/investin...
# 2   https://www.fool.com/investing/2025/01/13/why-...
# 3   https://www.investors.com/research/nvda-stock-...
# 4   https://www.businessinsider.com/elon-musk-buyi...
# 5   https://time.com/7205821/what-zuckerberg-risks...
# 6   https://www.wired.com/story/uncanny-valley-pod...
# 7   https://www.nasdaq.com/articles/why-did-apple-...
# 8   https://www.marketbeat.com/originals/meta-plat...
# 9   https://www.barchart.com/story/news/30623015/m...
# 10  https://www.thetimes.com/money-mentor/investin...
# 11  https://www.fool.com/investing/2025/01/13/why-...
# 12  https://www.investors.com/research/nvda-stock-...
# 13  https://www.businessinsider.com/elon-musk-buyi...
# 14  https://time.com/7205821/what-zuckerberg-risks...
# 15  https://www.wired.com/story/uncanny-valley-pod...
# 16  https://www.nasdaq.com/articles/why-did-apple-...
# 17  https://www.investopedia.com/dow-jones-today-0...
# 18  https://www.marketbeat.com/originals/meta-plat...
# 19  https://www.barchart.com/story/news/30623015/m...
#
#                                                reason
# 0   2025����지 META 종목은 ����� 대�����의 �����적인 정���과...
# 1   Meta shares have been volatile but have strong...
# 2   메�� ��������의 주식이 ��요일에 하���한 이��는 �����의 최고��...
# 3   Nvidia의 수��성이 개��되��다. 이는 Amazon과의 파트����과 1조 ...
# 4   Musk가 TikTok을 사는 것은 ���가능해 보이지만, 이상한 시대이기 때문에 ...
# 5   Meta의 CEO Mark Zuckerberg는 Meta가 �����에서 제3자 사...
# 6   메��의 ��������� 모����이션 정���이 바���면서 ����� 정부의 ...
# 7            AI 기���의 발전으로 인해 META 종목의 수��성이 개��되��다.
# 8   Meta의 ���고 모��은 최�� AI 기���을 ��용하여 개��되��다. 이로...
# 9                           2021�� 4분기 수��성이 개��되��다.
# 10  Meta shares have been volatile but have strong...
# 11  메�� ��������의 주식이 ��요일에 하���한 이��는 �����의 최고��...
# 12  Nvidia의 수��성이 개��되��다. 이는 Amazon과의 파트����과 1조 ...
# 13  Musk가 TikTok을 사는 것은 ���가능해 보이지만, 이상한 시대이기 때문에 ...
# 14  Meta의 CEO Mark Zuckerberg는 Meta가 �����에서 제3자 사...
# 15  메��의 ��������� 모����이션 정���이 바���면서 ����� 정부의 ...
# 16  Meta Platforms의 AI 기���은 �����성이 ���아지고 있으��, ...
# 17  Nvidia의 주가가 17% 하���하�� 시가�����이 5890�� ��러 ��...
# 18  Meta의 ���고 모��은 최�� AI 기���을 ��용하여 개��되��다. 이로...
# 19                          2021�� 4분기 수��성이 개��되��다.
